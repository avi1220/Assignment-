# %% [markdown]
# ### 1-- A python program to display all the header tags from ‘en.wikipedia.org/wiki/Main_Page’.

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

html = urlopen('https://en.wikipedia.org/wiki/Main_Page')
bs = BeautifulSoup(html, "html.parser")
ti = bs.find_all(['h1','h2','h3','h4','h5','h6'])
print('List all the header tags :',*ti, sep='\n\n')
# Out:
# List all the header tags :
#
# <h1 class="firstHeading" id="firstHeading" lang="en">Main Page</h1>
#
# <h2 class="mp-h2" id="mp-tfa-h2"><span id="From_today.27s_featured_article"></span><span class="mw-headline" id="From_today's_featured_article">From today's featured article</span></h2>
#
# <h2 class="mp-h2" id="mp-dyk-h2"><span class="mw-headline" id="Did_you_know_...">Did you know ...</span></h2>
#
# <h2 class="mp-h2" id="mp-itn-h2"><span class="mw-headline" id="In_the_news">In the news</span></h2>
#
# <h2 class="mp-h2" id="mp-otd-h2"><span class="mw-headline" id="On_this_day">On this day</span></h2>
#
# <h2 class="mp-h2" id="mp-tfp-h2"><span id="Today.27s_featured_picture"></span><span class="mw-headline" id="Today's_featured_picture">Today's featured picture</span></h2>
#
# <h2 class="mp-h2" id="mp-other"><span class="mw-headline" id="Other_areas_of_Wikipedia">Other areas of Wikipedia</span></h2>
#
# ...

# %% [markdown]
# ### 2--A python program to display IMDB’s Top rated 100 movies’ data(i.e. Name, IMDB rating, duration, director, star cast - 10 main characters)

# %%
from bs4 import BeautifulSoup
import requests
import re

# Download IMDB's Top 100 data
url = 'https://www.imdb.com/chart/top'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'lxml')

topmovies = soup.select('td.titleColumn')

crew = [a.attrs.get('title') for a in soup.select('td.titleColumn a')]
ratings = [b.attrs.get('data-value') for b in soup.select('td.posterColumn span[name=ir]')]


imdb_data= []

for index in range(0, len(topmovies)):
    
    movie_string = topmovies[index].get_text()
    movie = (' '.join(movie_string.split()).replace('.', ''))
    movie_title = movie[len(str(index))+1:-7]
    data = {"movie_title": movie_title,
            "star_cast": crew[index],
            "rating": ratings[index],
            }
    imdb_data.append(data)
    if len(imdb_data)==100:
        break

for item in imdb_data:
    print(item['movie_title'], '-',item['rating'] ,'Starring:', item['star_cast'])
# Out:
# The Shawshank Redemption - 9.22277683141955 Starring: Frank Darabont (dir.), Tim Robbins, Morgan Freeman
# The Godfather - 9.148667692392303 Starring: Francis Ford Coppola (dir.), Marlon Brando, Al Pacino
# The Godfather: Part II - 8.980943002253465 Starring: Francis Ford Coppola (dir.), Al Pacino, Robert De Niro
# The Dark Knight - 8.973504941902235 Starring: Christopher Nolan (dir.), Christian Bale, Heath Ledger
# 12 Angry Men - 8.930780941982919 Starring: Sidney Lumet (dir.), Henry Fonda, Lee J. Cobb
# Schindler's List - 8.90755447646196 Starring: Steven Spielberg (dir.), Liam Neeson, Ralph Fiennes
# The Lord of the Rings: The Return of the King - 8.883719031102416 Starring: Peter Jackson (dir.), Elijah Wood, Viggo Mortensen
# Pulp Fiction - 8.845001259629724 Starring: Quentin Tarantino (dir.), John Travolta, Uma Thurman
# Il buono, il brutto, il cattivo - 8.796070164147567 Starring: Sergio Leone (dir.), Clint Eastwood, Eli Wallach
# ...

# %% [markdown]
# ### 3--A python program to find geospatial coordinates (i.e. latitudes and longitudes) of a city name entered by user from ‘www.google.co.in/maps’.

# %%
# !pip install geopy

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="geoapiExercises")

address = input('enter your location -')
print("Location address:",address)
location = geolocator.geocode(address)
print("Latitude and Longitude of your location:")
print((location.latitude, location.longitude))
# Out:
# enter your location -gorakhpur
# Location address: gorakhpur
# Latitude and Longitude of your location:
# (26.67132865, 83.36458284327038)

# %% [markdown]
# ### 4--A python program to scrap book name, author name, genre and book review of 5 books from ‘www.bookpage.com’

# %%
import requests
from bs4 import BeautifulSoup

URL = 'https://www.bookpage.com'
page = requests.get(URL)

soup = BeautifulSoup(page.content, 'html.parser')

# %% [markdown]
# # 5--Write a python program to scrap cricket rankings from ‘www.icc-cricket.com’. You have to scrap:
# i) Top 10 ODI teams.
# ii) Top 10 ODI Batsmen
# iii) Top 10 ODI bowlers

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url='https://www.icc-cricket.com/rankings/mens/team-rankings/odi'
res = requests.get(url=url)

soup = BeautifulSoup(res.content)
teams= soup.find_all("table")[0]
df = pd.read_html(str(teams))[0]
df1=df.iloc[0:10,:]
df1
# Out:
#    Pos           Team T  Matches M  Points P  Rating R
# 0    1      England ENG         44      5405       123
# 1    2        India IND         49      5819       119
# 2    3   New Zealand NZ         32      3716       116
# 3    4    Australia AUS         36      3941       109
# 4    5  South Africa SA         31      3345       108
# 5    6     Pakistan PAK         32      3254       102
# 6    7   Bangladesh BAN         34      2989        88
# 7    8     Sri Lanka SL         39      3297        85
# 8    9   West Indies WI         43      3285        76
# 9   10  Afghanistan AFG         28      1549        55

# %%
#Top Ten ODI Teams
df1.drop(['Pos','Matches M','Points P','Rating R'],axis=1,inplace=True)
df1
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\pandas\core\frame.py:4102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#             Team T
# 0      England ENG
# 1        India IND
# 2   New Zealand NZ
# 3    Australia AUS
# 4  South Africa SA
# 5     Pakistan PAK
# 6   Bangladesh BAN
# 7     Sri Lanka SL
# 8   West Indies WI
# 9  Afghanistan AFG

# %%
url='https://www.icc-cricket.com/rankings/mens/player-rankings/odi'
res = requests.get(url=url)

soup = BeautifulSoup(res.content)
f = soup.find('div', {"class": "rankings-block__banner--name"})
players= soup.find_all("table")[0]
plr = pd.read_html(str(players))[0]

# %%
plr
# Out:
#                                                  Pos               Player  \
# 0                                                  2         Rohit Sharma
# 1                                                  3           Babar Azam
# 2                                                  4          Ross Taylor
# 3                                                  5  Francois du Plessis
# 4  6  This player has moved up in the rankings si...      Kane Williamson
# 5  7  This player has moved down in the rankings ...          Aaron Finch
# 6  8  This player has moved down in the rankings ...         David Warner
# 7                                                  9      Quinton de Kock
# 8  10  This player has moved up in the rankings s...       Jonny Bairstow
#
#   Team  Rating
# 0  IND     855
# 1  PAK     829
# 2   NZ     818
# 3   SA     790
# 4   NZ     765
# 5  AUS     762
# 6  AUS     759
# 7   SA     755
# 8  ENG     754

# %%
plr=plr.drop(['Pos','Team','Rating'],axis=1)

# %%
df=pd.DataFrame({'Player':[f.text]})
Batsman=pd.concat([df,plr],ignore_index=True)

#Top ten ODI Batsman
Batsman
# Out:
#                 Player
# 0          Virat Kohli
# 1         Rohit Sharma
# 2           Babar Azam
# 3          Ross Taylor
# 4  Francois du Plessis
# 5      Kane Williamson
# 6          Aaron Finch
# 7         David Warner
# 8      Quinton de Kock
# 9       Jonny Bairstow

# %%
url='https://www.icc-cricket.com/rankings/mens/player-rankings/odi'
res = requests.get(url=url)

soup = BeautifulSoup(res.content)
players= soup.find_all("table")[1]
plr = pd.read_html(str(players))[0]
plr
# Out:
#                                                  Pos            Player Team  \
# 0                                                  2    Jasprit Bumrah  IND
# 1                                                  3  Mujeeb Ur Rahman  AFG
# 2  4  This player has moved up in the rankings si...      Chris Woakes  ENG
# 3                                                  5     Kagiso Rabada   SA
# 4  6  This player has moved up in the rankings si...       Pat Cummins  AUS
# 5  7  This player has moved up in the rankings si...     Mohammad Amir  PAK
# 6  8  This player has moved down in the rankings ...    Josh Hazlewood  AUS
# 7  9  This player has moved up in the rankings si...        Matt Henry   NZ
# 8  10  This player has moved down in the rankings...      Jofra Archer  ENG
#
#    Rating
# 0     719
# 1     701
# 2     675
# 3     665
# 4     659
# 5     657
# 6     654
# 7     641
# 8     637

# %%
#Top ODI Bowlers
plr.drop(['Pos','Team','Rating'],axis=1,inplace=True)
plr
# Out:
#              Player
# 0    Jasprit Bumrah
# 1  Mujeeb Ur Rahman
# 2      Chris Woakes
# 3     Kagiso Rabada
# 4       Pat Cummins
# 5     Mohammad Amir
# 6    Josh Hazlewood
# 7        Matt Henry
# 8      Jofra Archer
